# %%
import numpy as np 
import pandas as pd 
train=pd.read_csv('/Users/darshthakkar/Downloads/fake-news/train.csv')
test=pd.read_csv('/Users/darshthakkar/Downloads/fake-news/test.csv')
#0: Reliable
#1: Unreliable

# %%
train.info()
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20800 entries, 0 to 20799
# Data columns (total 5 columns):
# id        20800 non-null int64
# title     20242 non-null object
# author    18843 non-null object
# text      20761 non-null object
# label     20800 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 812.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5200 entries, 0 to 5199
# Data columns (total 4 columns):
# id        5200 non-null int64
# title     5078 non-null object
# author    4697 non-null object
# text      5193 non-null object
# dtypes: int64(1), object(3)
# memory usage: 162.6+ KB

# %%
train['title'] = train['title'].astype(str)
train['title'] = train['title'].str.lower() 
train["title"] = train['title'].str.replace('[^\w\s]','')

# %%
train.head()
# Out:
#    id                                              title              author  \
# 0   0  house dem aide we didnt even see comeys letter...       Darrell Lucus
# 1   1  flynn hillary clinton big woman on campus  bre...     Daniel J. Flynn
# 2   2                  why the truth might get you fired  Consortiumnews.com
# 3   3  15 civilians killed in single us airstrike hav...     Jessica Purkiss
# 4   4  iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
test['title'] = test['title'].str.lower() 
test["title"] = test['title'].str.replace('[^\w\s]','')

# %%
#Wordcloud for the train.csv dataset.
import matplotlib.pyplot as plt
from wordcloud import WordCloud
text = " ".join(train['title'])
wordcloud = WordCloud().generate(text)
plt.figure()
plt.subplots(figsize=(15,12))
wordcloud = WordCloud(
    background_color="white",
    max_words=len(text),
    max_font_size=40,
    relative_scaling=.5).generate(text)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
test.head()
# Out:
#       id                                              title  \
# 0  20800  specter of trump loosens tongues if not purse ...
# 1  20801  russian warships ready to strike terrorists ne...
# 2  20802  nodapl native american leaders vow to stay all...
# 3  20803  tim tebow will attempt another comeback this t...
# 4  20804                       keiser report meme wars e995
#
#                     author                                               text
# 0         David Streitfeld  PALO ALTO, Calif.  —   After years of scorning...
# 1                      NaN  Russian warships ready to strike terrorists ne...
# 2            Common Dreams  Videos #NoDAPL: Native American Leaders Vow to...
# 3            Daniel Victor  If at first you don’t succeed, try a different...
# 4  Truth Broadcast Network  42 mins ago 1 Views 0 Comments 0 Likes 'For th...

# %%
#head for data labelled Unreliable
label1  = train.loc[train.label == 1]
label1.info()
label1.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10413 entries, 0 to 20799
# Data columns (total 5 columns):
# id        10413 non-null int64
# title     10413 non-null object
# author    8482 non-null object
# text      10374 non-null object
# label     10413 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 488.1+ KB
#     id                                              title              author  \
# 0    0  house dem aide we didnt even see comeys letter...       Darrell Lucus
# 2    2                  why the truth might get you fired  Consortiumnews.com
# 3    3  15 civilians killed in single us airstrike hav...     Jessica Purkiss
# 4    4  iranian woman jailed for fictional unpublished...      Howard Portnoy
# 6    6  life life of luxury elton johns 6 favorite sha...                 NaN
# 12  12  russian researchers discover secret nazi milit...       Amando Flavio
# 13  13  us officials see no link between trump and russia          Jason Ditz
# 14  14  re yes there are paid government trolls on soc...        AnotherAnnie
# 17  17  anonymous donor pays 25 million to release eve...            Starkman
# 18  18                           fbi closes in on hillary             The Doc
#
#                                                  text  label
# 0   House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 2   Why the Truth Might Get You Fired October 29, ...      1
# 3   Videos 15 Civilians Killed In Single US Airstr...      1
# 4   Print \nAn Iranian woman has been sentenced to...      1
# 6   Ever wonder how Britain’s most iconic pop pian...      1
# 12  The mystery surrounding The Third Reich and Na...      1
# 13  Clinton Campaign Demands FBI Affirm Trump's Ru...      1
# 14  Yes, There Are Paid Government Trolls On Socia...      1
# 17  A Caddo Nation tribal leader has just been fre...      1
# 18  FBI Closes In On Hillary! Posted on Home » Hea...      1

# %%
#Word Cloud for News labelled Unreliable
import matplotlib.pyplot as plt
from wordcloud import WordCloud
text = " ".join(label1['title'])
wordcloud = WordCloud().generate(text)
plt.figure()
plt.subplots(figsize=(15,12))
wordcloud = WordCloud(
    background_color="white",
    max_words=len(text),
    max_font_size=40,
    relative_scaling=.5).generate(text)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
#head for data labelled Unreliable
label0  = train.loc[train.label == 0]
label0.info()
label0.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10387 entries, 1 to 20797
# Data columns (total 5 columns):
# id        10387 non-null int64
# title     10387 non-null object
# author    10361 non-null object
# text      10387 non-null object
# label     10387 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 486.9+ KB
#     id                                              title  \
# 1    1  flynn hillary clinton big woman on campus  bre...
# 5    5  jackie mason hollywood would love trump if he ...
# 7    7  benoît hamon wins french socialist partys pres...
# 8    8  excerpts from a draft script for donald trumps...
# 9    9  a backchannel plan for ukraine and russia cour...
# 10  10  obamas organizing for action partners with sor...
# 11  11  bbc comedy sketch real housewives of isis caus...
# 15  15  in major league soccer argentines find a home ...
# 16  16  wells fargo chief abruptly steps down  the new...
# 19  19  chuck todd buzzfeed did donald trump a politic...
#
#                               author  \
# 1                    Daniel J. Flynn
# 5                    Daniel Nussbaum
# 7                    Alissa J. Rubin
# 8                                NaN
# 9       Megan Twohey and Scott Shane
# 10                       Aaron Klein
# 11                   Chris Tomlinson
# 15                     Jack Williams
# 16  Michael Corkery and Stacy Cowley
# 19                         Jeff Poor
#
#                                                  text  label
# 1   Ever get the feeling your life circles the rou...      0
# 5   In these trying times, Jackie Mason is the Voi...      0
# 7   PARIS  —   France chose an idealistic, traditi...      0
# 8   Donald J. Trump is scheduled to make a highly ...      0
# 9   A week before Michael T. Flynn resigned as nat...      0
# 10  Organizing for Action, the activist group that...      0
# 11  The BBC produced spoof on the “Real Housewives...      0
# 15  Guillermo Barros Schelotto was not the first A...      0
# 16  The scandal engulfing Wells Fargo toppled its ...      0
# 19  Wednesday after   Donald Trump’s press confere...      0

# %%
#Wordcloud for data labelled Reliable
text = " ".join(label0['title'])
wordcloud = WordCloud().generate(text)
plt.figure()
plt.subplots(figsize=(15,12))
wordcloud = WordCloud(
    background_color="white",
    max_words=len(text),
    max_font_size=40,
    relative_scaling=.5).generate(text)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
#Checking Nulls
test.isnull().sum()
train.isnull().sum()
# Out:
# id           0
# title        0
# author    1957
# text        39
# label        0
# dtype: int64

# %%
#Filling Nulls
test=test.fillna(' ')
train=train.fillna(' ')

# %%
#Concating all the columns to form a field- total, with title, author and text
test['total']=test['title']+' '+test['author']+test['text']
train['total']=train['title']+' '+train['author']+train['text']

# %%
#Importing Tfidf and CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %%
#Importing Tfidf and CountVectorizer
transformer = TfidfTransformer(smooth_idf=False)
count_vectorizer = CountVectorizer(ngram_range=(1, 2))
counts = count_vectorizer.fit_transform(train['total'].values)
tfidf = transformer.fit_transform(counts)
targets = train['label'].values
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(tfidf, targets, random_state=0)

# %%
#Checking Extratrees model Accuracy
from sklearn.ensemble import ExtraTreesClassifier
                    
Ex = ExtraTreesClassifier(n_estimators=5,n_jobs=4)
Ex.fit(X_train, y_train)
print('Accuracy of Extratrees classifier: {:.2f}'
     .format(Ex.score(X_test, y_test)))
# Out:
# Accuracy of Extratrees classifier: 0.83

# %%
#Checking RandomForest model Accuracy
from sklearn.ensemble import RandomForestClassifier

Rf = RandomForestClassifier(n_estimators=5,n_jobs=4)
Rf.fit(X_train, y_train)
print('Accuracy of RandomForest classifier: {:.2f}'
     .format(Rf.score(X_test, y_test)))
# Out:
# Accuracy of RandomForest classifier: 0.81

# %%
#Checking AdaBoost model Accuracy
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier

Ad= AdaBoostClassifier(DecisionTreeClassifier(max_depth=3),n_estimators=5)
Ad.fit(X_train, y_train)
print('Accuracy of Adaboost classifier: {:.2f}'
     .format(Ad.score(X_test, y_test)))
# Out:
# Accuracy of Adaboost classifier: 0.96

# %%
#Checking Multinomial Naive Bayes model Accuracy
from sklearn.naive_bayes import MultinomialNB

NB = MultinomialNB()
NB.fit(X_train, y_train)
print('Accuracy of NB: {:.2f}'
     .format(NB.score(X_test, y_test)))
# Out:
# Accuracy of NB: 0.79

# %%
#Preparing Test Data for Predictions
print(test.shape)
test_data = test.copy()
print(test_data.shape)
test_counts = count_vectorizer.transform(test['total'].values)
test_tfidf = transformer.fit_transform(test_counts)
# Out:
# (5200, 5)
# (5200, 5)
# /Users/darshthakkar/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:1278: RuntimeWarning: divide by zero encountered in true_divide
#   idf = np.log(n_samples / df) + 1

# %%
#Applying Adaboost model to predict the labels of test.csv
AdabM = Ad.predict(test_counts)
predictions = pd.DataFrame({'id':test.id, 'label':AdabM})
predictions.shape
# Out:
# (5200, 2)

# %%
predictions.head()
# Out:
#       id  label
# 0  20800      0
# 1  20801      1
# 2  20802      1
# 3  20803      0
# 4  20804      1

# %%
test.head()
# Out:
#       id                                              title  \
# 0  20800  specter of trump loosens tongues if not purse ...
# 1  20801  russian warships ready to strike terrorists ne...
# 2  20802  nodapl native american leaders vow to stay all...
# 3  20803  tim tebow will attempt another comeback this t...
# 4  20804                       keiser report meme wars e995
#
#                     author                                               text  \
# 0         David Streitfeld  PALO ALTO, Calif.  —   After years of scorning...
# 1                           Russian warships ready to strike terrorists ne...
# 2            Common Dreams  Videos #NoDAPL: Native American Leaders Vow to...
# 3            Daniel Victor  If at first you don’t succeed, try a different...
# 4  Truth Broadcast Network  42 mins ago 1 Views 0 Comments 0 Likes 'For th...
#
#                                                total
# 0  specter of trump loosens tongues if not purse ...
# 1  russian warships ready to strike terrorists ne...
# 2  nodapl native american leaders vow to stay all...
# 3  tim tebow will attempt another comeback this t...
# 4  keiser report meme wars e995 Truth Broadcast N...

# %%
test = test.drop(['total'], axis = 1)

# %%
test['label'] = predictions['label']

# %%
test.head()
# Out:
#       id                                              title  \
# 0  20800  specter of trump loosens tongues if not purse ...
# 1  20801  russian warships ready to strike terrorists ne...
# 2  20802  nodapl native american leaders vow to stay all...
# 3  20803  tim tebow will attempt another comeback this t...
# 4  20804                       keiser report meme wars e995
#
#                     author                                               text  \
# 0         David Streitfeld  PALO ALTO, Calif.  —   After years of scorning...
# 1                           Russian warships ready to strike terrorists ne...
# 2            Common Dreams  Videos #NoDAPL: Native American Leaders Vow to...
# 3            Daniel Victor  If at first you don’t succeed, try a different...
# 4  Truth Broadcast Network  42 mins ago 1 Views 0 Comments 0 Likes 'For th...
#
#    label
# 0      0
# 1      1
# 2      1
# 3      0
# 4      1

# %%
test.to_csv('/Users/darshthakkar/Downloads/fake-news/testpredictions.csv')
